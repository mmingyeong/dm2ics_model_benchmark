# %%
import sys
import os

# 평가 클래스 및 분석 유틸 불러오기
sys.path.append("/home/users/mmingyeong/_dm2ics_model_benchmark/dm2ics_model_benchmark/evaluation")

from evaluator import Evaluator

# %%
# 파일 경로 지정 (예: ViT 예시)
input_file = "/caefs/data/IllustrisTNG/subcube/input/subcubes_stride4_50mpc_010.h5"
target_file = "/caefs/data/IllustrisTNG/subcube/output/subcubes_stride4_50mpc_010.h5"
#prediction_file = "/caefs/data/IllustrisTNG/predictions/vit/Sample1_epoch30/subcubes_stride4_50mpc_010.h5"
prediction_file = "/caefs/data/IllustrisTNG/predictions/unet/Sample100_epoch100/subcubes_stride4_50mpc_010.h5"
log_file = "../results/vit_test/vit_full_3dreg_sample1_epoch30_log_train.csv"

# %%
# Subcube index 및 box size
index = 42
box_size = 50.0  # Mpc/h

# Evaluator 생성
evaluator = Evaluator(
    input_file=input_file,
    target_file=target_file,
    prediction_file=prediction_file,
    log_file=log_file,
    index=index,
    box_size=box_size,
    show=True
)

# %%
evaluator.evaluate_all()
# Out:
# 2025-07-31 16:52:08,507 [INFO] 🔍 Starting full evaluation...
# 2025-07-31 16:52:08,511 [INFO] 📉 Plotting loss curve...
# 2025-07-31 16:52:08,852 [INFO] 📉 Loss curve saved to unet_Sample100_epoch100_results/loss_curve.png
# 2025-07-31 16:52:09,664 [INFO] 🖼️  Projection comparison saved to unet_Sample100_epoch100_results/unet_projection_idx42_axis0.png
# 2025-07-31 16:52:10,626 [INFO] 📊 Pixel scatter plot saved to unet_Sample100_epoch100_results/unet_scatter_idx42.png
# 2025-07-31 16:52:10,906 [INFO] field: ArrayMesh() painting done
# [ 000000.04 ]   0: 07-31 16:52  MeshSource      INFO     field: ArrayMesh() painting done
# 2025-07-31 16:52:10,951 [INFO] field: ArrayMesh() painting done
# [ 000000.08 ]   0: 07-31 16:52  MeshSource      INFO     field: ArrayMesh() painting done
# 2025-07-31 16:52:10,985 [INFO] field: ArrayMesh() painting done
# [ 000000.12 ]   0: 07-31 16:52  MeshSource      INFO     field: ArrayMesh() painting done
# 2025-07-31 16:52:10,989 [INFO] field: ArrayMesh() painting done
# [ 000000.12 ]   0: 07-31 16:52  MeshSource      INFO     field: ArrayMesh() painting done
# /caefs/user/mmingyeong/_dm2ics_model_benchmark/dm2ics_model_benchmark/evaluation/nbodykit_analyzer.py:45: RuntimeWarning: invalid value encountered in true_divide
#   self.T_k = self.P_pred / self.P_true
# /caefs/user/mmingyeong/_dm2ics_model_benchmark/dm2ics_model_benchmark/evaluation/nbodykit_analyzer.py:46: RuntimeWarning: invalid value encountered in true_divide
#   self.C_k = self.P_cross / np.sqrt(self.P_true * self.P_pred)
# 📊 Saved power spectrum to: unet_Sample100_epoch100_results/power_spectrum_comparison.png
# 📈 Saved transfer function to: unet_Sample100_epoch100_results/transfer_function.png
# 🔗 Saved correlation coefficient to: unet_Sample100_epoch100_results/correlation_coefficient.png
# ✅ All analysis completed. Results saved to: unet_Sample100_epoch100_results
# 2025-07-31 16:52:13,287 [INFO] 📈 Gaussianity plot saved to unet_Sample100_epoch100_results/unet_gaussianity_idx42_log1p.png
# [ 000002.42 ]   0: 07-31 16:52  root            INFO     📈 Gaussianity plot saved to unet_Sample100_epoch100_results/unet_gaussianity_idx42_log1p.png
# 2025-07-31 16:52:18,150 [INFO] 📉 PDF comparison saved to: unet_Sample100_epoch100_results/unet_pdf_comparison_idx42_log1p.png
# [ 000007.28 ]   0: 07-31 16:52  root            INFO     📉 PDF comparison saved to: unet_Sample100_epoch100_results/unet_pdf_comparison_idx42_log1p.png
# 2025-07-31 16:52:18,341 [INFO] ✅ All evaluations completed and saved to unet_Sample100_epoch100_results
# [ 000007.47 ]   0: 07-31 16:52  root            INFO     ✅ All evaluations completed and saved to unet_Sample100_epoch100_results

# %%
# 저장 디렉토리 출력
evaluator.output_dir
# Out:
# 'unet_Sample100_epoch100_results'

# %%
import os
for fname in sorted(os.listdir(evaluator.output_dir)):
    print("📁", fname)
# Out:
# 📁 correlation_coefficient.png
# 📁 loss_curve.png
# 📁 power_spectrum_comparison.png
# 📁 transfer_function.png
# 📁 unet_gaussianity_idx42_log1p.png
# 📁 unet_pdf_comparison_idx42_log1p.png
# 📁 unet_projection_idx42_axis0.png
# 📁 unet_scatter_idx42.png
