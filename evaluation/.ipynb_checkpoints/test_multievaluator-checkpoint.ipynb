# %%
# Cell 0: 환경 설정
import sys
import os
sys.path.append("..")  # 프로젝트 최상단 경로 추가

from multi_evaluator import MultiEvaluator

# %%
# Cell 1: 경로 지정
input_file = "/caefs/data/IllustrisTNG/subcube/input/subcubes_stride4_50mpc_010.h5"
target_file = "/caefs/data/IllustrisTNG/subcube/output/subcubes_stride4_50mpc_010.h5"

prediction_infos = [
    {
        "file": "/caefs/data/IllustrisTNG/predictions/unet/Sample1_epoch30/subcubes_stride4_50mpc_010.h5",
        "label": "U-Net epoch30",
        "log_file": "../results/unet_test/unet_full_3dreg_sample1_epoch30_log_train.csv"
    },
    {
        "file": "/caefs/data/IllustrisTNG/predictions/fno/Sample1_epoch30/subcubes_stride4_50mpc_010.h5",
        "label": "FNO epoch30",
        "log_file": "../results/fno_test/fno_full_3dreg_sample1_epoch30_log_train.csv"
    },
    {
        "file": "/caefs/data/IllustrisTNG/predictions/vit/Sample1_epoch30/subcubes_stride4_50mpc_010.h5",
        "label": "ViT epoch30",
        "log_file": "../results/vit_test/vit_full_3dreg_sample1_epoch30_log_train.csv"
    },
]

# %%
prediction_infos = [
    {
        "file": "/caefs/data/IllustrisTNG/predictions/unet/Sample100_epoch100/subcubes_stride4_50mpc_010.h5",
        "label": "U-Net epoch100",
        "log_file": "../results/unet_test/unet_full_3dreg_Sample100_epoch100_log_train.csv"
    }
]

evaluator = MultiEvaluator(
    input_file="/caefs/data/IllustrisTNG/subcube/input/subcubes_stride4_50mpc_010.h5",
    target_file="/caefs/data/IllustrisTNG/subcube/output/subcubes_stride4_50mpc_010.h5",
    prediction_infos=prediction_infos,
    index=42,
    box_size=50.0,
    show=True
)
evaluator.plot_loss_curve(label="ViT epoch30", log_file="../results/vit_test/vit_full_3dreg_sample1_epoch30_log_train.csv")
# evaluator.evaluate_all(mode="Unified")
# Out:
# 2025-07-31 19:09:04,995 [INFO] 📉 Plotting loss curve for ViT epoch30 from ../results/vit_test/vit_full_3dreg_sample1_epoch30_log_train.csv
# 2025-07-31 19:09:05,501 [INFO] 📉 Multi loss curve saved to multi_eval_Sample42/ViT_epoch30/multi_loss_curve.png
